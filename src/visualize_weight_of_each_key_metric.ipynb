# %%
import pandas as pd
import matplotlib.pyplot as plt
#Generate a pie chart to show the weight of each key metric
labels=['PTS', 'STL', 'AST', 'TOV']
#The weight of each metric has been manually adjusted
plt.pie(['0.61', '0.11', '0.07', '0.21'], labels=labels, autopct='%1.2f%%')
plt.title('Weight of Each Key Metric')
plt.legend()
plt.show()
